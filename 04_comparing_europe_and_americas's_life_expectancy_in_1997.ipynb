# %% [markdown]
# <a href="https://colab.research.google.com/github/LiTaokui/Data_Visualization/blob/main/04_comparing_europe_and_americas's_life_expectancy_in_1997.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("/content/sample_data/countries.csv")
data
# Out:
#           country continent  year  lifeExpectancy  population  gdpPerCapita
# 0     Afghanistan      Asia  1952          28.801     8425333    779.445314
# 1     Afghanistan      Asia  1957          30.332     9240934    820.853030
# 2     Afghanistan      Asia  1962          31.997    10267083    853.100710
# 3     Afghanistan      Asia  1967          34.020    11537966    836.197138
# 4     Afghanistan      Asia  1972          36.088    13079460    739.981106
# ...           ...       ...   ...             ...         ...           ...
# 1699     Zimbabwe    Africa  1987          62.351     9216418    706.157306
# 1700     Zimbabwe    Africa  1992          60.377    10704340    693.420786
# 1701     Zimbabwe    Africa  1997          46.809    11404948    792.449960
# 1702     Zimbabwe    Africa  2002          39.989    11926563    672.038623
# 1703     Zimbabwe    Africa  2007          43.487    12311143    469.709298
#
# [1704 rows x 6 columns]

# %%
set(data.continent)
# Out:
# {'Africa', 'Americas', 'Asia', 'Europe', 'Oceania'}

# %%
data_1997 = data[data.year == 1997]
data_1997
# Out:
#                  country continent  ...  population  gdpPerCapita
# 9            Afghanistan      Asia  ...    22227415    635.341351
# 21               Albania    Europe  ...     3428038   3193.054604
# 33               Algeria    Africa  ...    29072015   4797.295051
# 45                Angola    Africa  ...     9875024   2277.140884
# 57             Argentina  Americas  ...    36203463  10967.281950
# ...                  ...       ...  ...         ...           ...
# 1653             Vietnam      Asia  ...    76048996   1385.896769
# 1665  West Bank and Gaza      Asia  ...     2826046   7110.667619
# 1677         Yemen, Rep.      Asia  ...    15826497   2117.484526
# 1689              Zambia    Africa  ...     9417789   1071.353818
# 1701            Zimbabwe    Africa  ...    11404948    792.449960
#
# [142 rows x 6 columns]

# %%
europe_1997 = data_1997[data_1997.continent == "Europe"]
europe_1997
# Out:
#                      country continent  ...  population  gdpPerCapita
# 21                   Albania    Europe  ...     3428038   3193.054604
# 81                   Austria    Europe  ...     8069876  29095.920660
# 117                  Belgium    Europe  ...    10199787  27561.196630
# 153   Bosnia and Herzegovina    Europe  ...     3607000   4766.355904
# 189                 Bulgaria    Europe  ...     8066057   5970.388760
# 381                  Croatia    Europe  ...     4444595   9875.604515
# 405           Czech Republic    Europe  ...    10300707  16048.514240
# 417                  Denmark    Europe  ...     5283663  29804.345670
# 525                  Finland    Europe  ...     5134406  23723.950200
# 537                   France    Europe  ...    58623428  25889.784870
# 573                  Germany    Europe  ...    82011073  27788.884160
# 597                   Greece    Europe  ...    10502372  18747.698140
# ...

# %%
america_1997 = data_1997[data_1997.continent == "Americas"]
america_1997
# Out:
#                   country continent  ...  population  gdpPerCapita
# 57              Argentina  Americas  ...    36203463  10967.281950
# 141               Bolivia  Americas  ...     7693188   3326.143191
# 177                Brazil  Americas  ...   168546719   7957.980824
# 249                Canada  Americas  ...    30305843  28954.925890
# 285                 Chile  Americas  ...    14599929  10118.053180
# 309              Colombia  Americas  ...    37657830   6117.361746
# 357            Costa Rica  Americas  ...     3518107   6677.045314
# 393                  Cuba  Americas  ...    10983007   5431.990415
# 441    Dominican Republic  Americas  ...     7992357   3614.101285
# 453               Ecuador  Americas  ...    11911819   7429.455877
# 477           El Salvador  Americas  ...     5783439   5154.825496
# 609             Guatemala  Americas  ...     9803875   4684.313807
# 645                 Haiti  Americas  ...     6913545   1341.726931
# ...

# %%
len(europe_1997)
# Out:
# 30

# %%
len(america_1997)
# Out:
# 25

# %%
print("mean lifeExpectancy in europe")
print(europe_1997.lifeExpectancy.mean())

print("mean lifeExpectancy in america")
print(america_1997.lifeExpectancy.mean())

print("median lifeExpectancy in europe")
print(europe_1997.lifeExpectancy.median())

print("median lifeExpectancy in america")
print(america_1997.lifeExpectancy.median())
# Out:
# mean lifeExpectancy in europe
# 75.50516666666667
# mean lifeExpectancy in america
# 71.15048
# median lifeExpectancy in europe
# 76.116
# median lifeExpectancy in america
# 72.146

# %%
plt.hist(europe_1997.lifeExpectancy, 10, edgecolor="black")
# Out:
# (array([2., 1., 1., 4., 3., 1., 4., 2., 6., 6.]),
#  array([68.835 , 69.8905, 70.946 , 72.0015, 73.057 , 74.1125, 75.168 ,
#         76.2235, 77.279 , 78.3345, 79.39  ]),
#  <a list of 10 Patch objects>)

# %%
plt.subplot(2,1,1)
plt.hist(europe_1997.lifeExpectancy, 20, range=(50,85), edgecolor="black")
plt.ylabel("europe")
plt.title("distribution of lifeExpectancy")

plt.subplot(2,1,2)
plt.hist(america_1997.lifeExpectancy, 20, range=(50,85), edgecolor="black")
plt.ylabel("america")
# Out:
# Text(0, 0.5, 'america')

# %%
america_1997[america_1997.lifeExpectancy < 65]
# Out:
#      country continent  year  lifeExpectancy  population  gdpPerCapita
# 141  Bolivia  Americas  1997          62.050     7693188   3326.143191
# 645    Haiti  Americas  1997          56.671     6913545   1341.726931
