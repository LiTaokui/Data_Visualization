# %% [markdown]
# <a href="https://colab.research.google.com/github/LiTaokui/Data_Visualization/blob/main/09_comparing_population_of_most_populous_countries.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("/content/sample_data/countries.csv")
data
# Out:
#           country continent  year  lifeExpectancy  population  gdpPerCapita
# 0     Afghanistan      Asia  1952          28.801     8425333    779.445314
# 1     Afghanistan      Asia  1957          30.332     9240934    820.853030
# 2     Afghanistan      Asia  1962          31.997    10267083    853.100710
# 3     Afghanistan      Asia  1967          34.020    11537966    836.197138
# 4     Afghanistan      Asia  1972          36.088    13079460    739.981106
# ...           ...       ...   ...             ...         ...           ...
# 1699     Zimbabwe    Africa  1987          62.351     9216418    706.157306
# 1700     Zimbabwe    Africa  1992          60.377    10704340    693.420786
# 1701     Zimbabwe    Africa  1997          46.809    11404948    792.449960
# 1702     Zimbabwe    Africa  2002          39.989    11926563    672.038623
# 1703     Zimbabwe    Africa  2007          43.487    12311143    469.709298
#
# [1704 rows x 6 columns]

# %%
data_2007 = data[data.year == 2007]
data_2007
# Out:
#                  country continent  ...  population  gdpPerCapita
# 11           Afghanistan      Asia  ...    31889923    974.580338
# 23               Albania    Europe  ...     3600523   5937.029526
# 35               Algeria    Africa  ...    33333216   6223.367465
# 47                Angola    Africa  ...    12420476   4797.231267
# 59             Argentina  Americas  ...    40301927  12779.379640
# ...                  ...       ...  ...         ...           ...
# 1655             Vietnam      Asia  ...    85262356   2441.576404
# 1667  West Bank and Gaza      Asia  ...     4018332   3025.349798
# 1679         Yemen, Rep.      Asia  ...    22211743   2280.769906
# 1691              Zambia    Africa  ...    11746035   1271.211593
# 1703            Zimbabwe    Africa  ...    12311143    469.709298
#
# [142 rows x 6 columns]

# %%
top10 = data_2007.sort_values("population", ascending=False).head(10)

# %%
x = range(10)
plt.bar(x, top10.population / 10**6)
plt.xticks(x, top10.country, rotation="vertical")
plt.ylabel("population in millions")
# Out:
# Text(0, 0.5, 'population in millions')
