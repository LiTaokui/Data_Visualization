# %% [markdown]
# <a href="https://colab.research.google.com/github/LiTaokui/Data_Visualization/blob/main/03_comparing_asia_and_europe's_GDP_per_capita.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("/datalab/Data_Visualization/countries.csv")
data
# Out:
#           country continent  year  lifeExpectancy  population  gdpPerCapita
# 0     Afghanistan      Asia  1952          28.801     8425333    779.445314
# 1     Afghanistan      Asia  1957          30.332     9240934    820.853030
# 2     Afghanistan      Asia  1962          31.997    10267083    853.100710
# 3     Afghanistan      Asia  1967          34.020    11537966    836.197138
# 4     Afghanistan      Asia  1972          36.088    13079460    739.981106
# ...           ...       ...   ...             ...         ...           ...
# 1699     Zimbabwe    Africa  1987          62.351     9216418    706.157306
# 1700     Zimbabwe    Africa  1992          60.377    10704340    693.420786
# 1701     Zimbabwe    Africa  1997          46.809    11404948    792.449960
# 1702     Zimbabwe    Africa  2002          39.989    11926563    672.038623
# 1703     Zimbabwe    Africa  2007          43.487    12311143    469.709298
#
# [1704 rows x 6 columns]

# %%
set(data.continent)
# Out:
# {'Africa', 'Americas', 'Asia', 'Europe', 'Oceania'}

# %%
data_2007 = data[data.year == 2007]
data_2007
# Out:
#                  country continent  ...  population  gdpPerCapita
# 11           Afghanistan      Asia  ...    31889923    974.580338
# 23               Albania    Europe  ...     3600523   5937.029526
# 35               Algeria    Africa  ...    33333216   6223.367465
# 47                Angola    Africa  ...    12420476   4797.231267
# 59             Argentina  Americas  ...    40301927  12779.379640
# ...                  ...       ...  ...         ...           ...
# 1655             Vietnam      Asia  ...    85262356   2441.576404
# 1667  West Bank and Gaza      Asia  ...     4018332   3025.349798
# 1679         Yemen, Rep.      Asia  ...    22211743   2280.769906
# 1691              Zambia    Africa  ...    11746035   1271.211593
# 1703            Zimbabwe    Africa  ...    12311143    469.709298
#
# [142 rows x 6 columns]

# %%
asia_2007 = data_2007[data_2007.continent == "Asia"]
asia_2007
# Out:
#                  country continent  ...  population  gdpPerCapita
# 11           Afghanistan      Asia  ...    31889923    974.580338
# 95               Bahrain      Asia  ...      708573  29796.048340
# 107           Bangladesh      Asia  ...   150448339   1391.253792
# 227             Cambodia      Asia  ...    14131858   1713.778686
# 299                China      Asia  ...  1318683096   4959.114854
# 671     Hong Kong, China      Asia  ...     6980412  39724.978670
# 707                India      Asia  ...  1110396331   2452.210407
# 719            Indonesia      Asia  ...   223547000   3540.651564
# 731                 Iran      Asia  ...    69453570  11605.714490
# 743                 Iraq      Asia  ...    27499638   4471.061906
# 767               Israel      Asia  ...     6426679  25523.277100
# 803                Japan      Asia  ...   127467972  31656.068060
# 815               Jordan      Asia  ...     6053193   4519.461171
# ...

# %%
europe_2007 = data_2007[data_2007.continent == "Europe"]
europe_2007
# Out:
#                      country continent  ...  population  gdpPerCapita
# 23                   Albania    Europe  ...     3600523   5937.029526
# 83                   Austria    Europe  ...     8199783  36126.492700
# 119                  Belgium    Europe  ...    10392226  33692.605080
# 155   Bosnia and Herzegovina    Europe  ...     4552198   7446.298803
# 191                 Bulgaria    Europe  ...     7322858  10680.792820
# 383                  Croatia    Europe  ...     4493312  14619.222720
# 407           Czech Republic    Europe  ...    10228744  22833.308510
# 419                  Denmark    Europe  ...     5468120  35278.418740
# 527                  Finland    Europe  ...     5238460  33207.084400
# 539                   France    Europe  ...    61083916  30470.016700
# 575                  Germany    Europe  ...    82400996  32170.374420
# 599                   Greece    Europe  ...    10706290  27538.411880
# ...

# %%
len(set(asia_2007.country))
# Out:
# 33

# %%
len(set(europe_2007.country))
# Out:
# 30

# %%
print("mean gdp per capita in asia")
print(asia_2007.gdpPerCapita.mean())

print("mean gdp per capita in europe")
print(europe_2007.gdpPerCapita.mean())

print("median gdp per capita in asia")
print(asia_2007.gdpPerCapita.median())

print("median gdp per capita in europe")
print(europe_2007.gdpPerCapita.median())
# Out:
# mean gdp per capita in asia
# 12473.02687013333
# mean gdp per capita in europe
# 25054.481635933327
# median gdp per capita in asia
# 4471.061906
# median gdp per capita in europe
# 28054.06579

# %%
plt.hist(asia_2007.gdpPerCapita, 10, edgecolor="red")
# Out:
# (array([19.,  1.,  3.,  0.,  3.,  2.,  2.,  0.,  1.,  2.]),
#  array([  944.      ,  5580.298978, 10216.597956, 14852.896934,
#         19489.195912, 24125.49489 , 28761.793868, 33398.092846,
#         38034.391824, 42670.690802, 47306.98978 ]),
#  <a list of 10 Patch objects>)

# %%
plt.subplot(2, 1, 1)
plt.hist(asia_2007.gdpPerCapita, 20, range=(0,50000), edgecolor="black")
plt.ylabel("asia")
plt.title("distribution of gdpPerCapita")

plt.subplot(2, 1, 2)
plt.hist(europe_2007.gdpPerCapita, 20, range=(0,50000), edgecolor="black")
plt.ylabel("europe")
# Out:
# Text(0, 0.5, 'europe')
